# %% [markdown]
# <a href="https://colab.research.google.com/github/durgeshchavan25-svg/Data_Science_Lab/blob/main/practical_no1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Python Program to compute factorial of a given number

def factorial(n):
    if n < 0:
        return "Factorial does not exist for negative numbers"
    elif n == 0:
        return 1
    else:
        fact = 1
        for i in range(1, n + 1):
            fact *= i
        return fact

# Get input from the user
try:
    num = int(input("Enter a non-negative integer: "))
    result = factorial(num)
    print(f"The factorial of {num} is {result}")
except ValueError:
    print("Invalid input. Please enter an integer.")
# Out:
# Enter a non-negative integer: 6
# The factorial of 6 is 720

# %%
# Python Program to display table for a given number

def display_multiplication_table(num):
    print(f"Multiplication Table for {num}:")
    for i in range(1, 11):  # Table up to 10
        print(f"{num} x {i} = {num * i}")

# Get input from the user
try:
    number = int(input("Enter a number to display its multiplication table: "))
    display_multiplication_table(number)
except ValueError:
    print("Invalid input. Please enter an integer.")
# Out:
# Enter a number to display its multiplication table: 9
# Multiplication Table for 9:
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81
# 9 x 10 = 90

# %%
# Python Program to identify the given number is odd or even
def check_odd_even(num):
    if num % 2 == 0:
        return "Even"
    else:
        return "Odd"

# Get input from the user
try:
    number = int(input("Enter an integer: "))
    result = check_odd_even(number)
    print(f"The number {number} is {result}.")
except ValueError:
    print("Invalid input. Please enter an integer.")
# Out:
# Enter an integer: 24
# The number 24 is Even.

# %%
# Python Program to identify the entered number is palindrome or not.

def is_palindrome(num):
    # Convert the number to a string to easily reverse it
    num_str = str(num)
    # Compare the string with its reversed version
    return num_str == num_str[::-1]

# Get input from the user
try:
    number = int(input("Enter an integer to check if it's a palindrome: "))
    if is_palindrome(number):
        print(f"The number {number} is a palindrome.")
    else:
        print(f"The number {number} is not a palindrome.")
except ValueError:
    print("Invalid input. Please enter an integer.")
# Out:
# Enter an integer to check if it's a palindrome: 12
# The number 12 is not a palindrome.

# %%
print("Welcome to the Engineering Field Advisor!\n")
print("Please answer the following questions to help us suggest a suitable engineering field.\n")

# Take user inputs
interest = input("Do you like working with Computers, Machines, or Buildings? ").strip().lower()
skill = input("Do you enjoy Programming, Mechanics, or Design? ").strip().lower()

# Decision-making using if-else with simple subjects
if interest == "computers" and skill == "programming":
    field = "Computer Engineering or Software Engineering"
    subjects = ["Programming", "Algorithms", "Software Development"]
elif interest == "machines" and skill == "mechanics":
    field = "Mechanical Engineering"
    subjects = ["Mechanics", "Thermodynamics", "Machine Design"]
elif interest == "buildings" and skill == "design":
    field = "Civil Engineering"
    subjects = ["Design", "Surveying", "Construction Materials"]
elif interest == "computers" and skill == "design":
    field = "Information Technology or Computer Science"
    subjects = ["Networking", "Databases", "Software"]
elif interest == "machines" and skill == "design":
    field = "Industrial Engineering"
    subjects = ["Production", "Planning", "Operations"]
else:
    field = "Interdisciplinary Fields like Mechatronics"
    subjects = ["Robotics", "Embedded Systems", "AI"]

# Display the suggestion
print("\nBased on your answers, a suitable engineering field for you could be:")
print(field)
print("Recommended subjects to focus on:")
for subject in subjects:
    print("-", subject)
# Out:
# Welcome to the Engineering Field Advisor!
#
# Please answer the following questions to help us suggest a suitable engineering field.
#
# Do you like working with Computers, Machines, or Buildings? computer
# Do you enjoy Programming, Mechanics, or Design? programming
#
# Based on your answers, a suitable engineering field for you could be:
# Interdisciplinary Fields like Mechatronics
# Recommended subjects to focus on:
# - Robotics
# - Embedded Systems
# - AI
